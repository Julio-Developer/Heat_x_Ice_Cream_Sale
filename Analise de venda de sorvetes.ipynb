# %% [markdown]
# ## Analisando a relação do calor com a venda de sorvetes

# %% [markdown]
# #### Esse propjeto, precisa mostrar a relação do aumento de temperatura com o aumento de venda de sorvetes
#
# - Deve ficar identica a esse:
#
# ![image.png](attachment:bf12d32c-175f-4eb6-acfe-64e292a8c9db.png)

# %% [markdown]
# #### Importando as bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Colocando lendo o dataset

# %%
df = pd.read_csv('icecream_sales new.csv')

# %% [markdown]
# #### Verificando como os dados estão dispostos no data set

# %%
# VErificando as 10 primeiras linhas

df.head(10)
# Out:
#    Temperature  Sales
# 0           37    292
# 1           40    228
# 2           49    324
# 3           61    376
# 4           72    440
# 5           79    496
# 6           83    536
# 7           81    556
# 8           75    496
# 9           64    412

# %%
# Verificando as 10 ultimas linhas

df.tail(10)
# Out:
#     Temperature  Sales
# 2            49    324
# 3            61    376
# 4            72    440
# 5            79    496
# 6            83    536
# 7            81    556
# 8            75    496
# 9            64    412
# 10           53    324
# 11           42    320

# %%
# Resumo estatístico geral do dataset

df.describe()
# Out:
#        Temperature       Sales
# count    12.000000   12.000000
# mean     61.333333  400.000000
# std      16.837908  105.651227
# min      37.000000  228.000000
# 25%      47.250000  323.000000
# 50%      62.500000  394.000000
# 75%      76.000000  496.000000
# max      83.000000  556.000000

# %%
# Verificando a estrutura do dataset

df.shape
# Out:
# (12, 2)

# %%
# Verificando a existencia de valores nulos

df.isnull().sum()
# Out:
# Temperature    0
# Sales          0
# dtype: int64

# %%
# Convertendo fahrenheit para celsius

convert_temperature = (df['Temperature'] - 32) * 5/9
df['Temperature'] = convert_temperature
df
# Out:
#     Temperature  Sales
# 0      2.777778    292
# 1      4.444444    228
# 2      9.444444    324
# 3     16.111111    376
# 4     22.222222    440
# 5     26.111111    496
# 6     28.333333    536
# 7     27.222222    556
# 8     23.888889    496
# 9     17.777778    412
# 10    11.666667    324
# 11     5.555556    320

# %%
# Convertendo dolar para real

conver_dolar = (df['Sales'] * 5.35)
df['Sales'] = conver_dolar

df
# Out:
#     Temperature   Sales
# 0      2.777778  1562.2
# 1      4.444444  1219.8
# 2      9.444444  1733.4
# 3     16.111111  2011.6
# 4     22.222222  2354.0
# 5     26.111111  2653.6
# 6     28.333333  2867.6
# 7     27.222222  2974.6
# 8     23.888889  2653.6
# 9     17.777778  2204.2
# 10    11.666667  1733.4
# 11     5.555556  1712.0

# %% [markdown]
# #### Começando a construção do gráfico

# %%
# Organizando os dado em ordem crescente
order = df.sort_values('Temperature', ascending=False)
order
# Out:
#     Temperature   Sales
# 6     28.333333  2867.6
# 7     27.222222  2974.6
# 5     26.111111  2653.6
# 8     23.888889  2653.6
# 4     22.222222  2354.0
# 9     17.777778  2204.2
# 3     16.111111  2011.6
# 10    11.666667  1733.4
# 2      9.444444  1733.4
# 11     5.555556  1712.0
# 1      4.444444  1219.8
# 0      2.777778  1562.2

# %%
# Construindo o gráfico solicitado

# Definindo um style

plt.style.use('grayscale')

# Definindo o titulo
plt.title('Ice Cream Truck')

# Construindo o grafico e colocando estilo
plt.plot(order['Temperature'], 
         order['Sales'],
         color = 'red',
         marker = '.',
         linestyle = '--',
         label = 'R$')

# Definindo o nome dos eixos
plt.xlabel('Temperature (celsius)')
plt.ylabel('Sales (R$)')
plt.legend()

#Salvando o arquivo em um png
plt.savefig('grafico sorvetes.png')

# Mostrando todos os graficos
plt.show()
